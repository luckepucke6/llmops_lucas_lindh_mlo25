# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke?"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output='Why don\'t math students like to play hide and seek with their test scores?\n\nBecause they always end up "under" each other! 🧮✨')

# %%
print(result.output)
# Out:
# Why don't math students like to play hide and seek with their test scores?
#
# Because they always end up "under" each other! 🧮✨

# %%
result = await agent.run("What is the weather in Stockholm today?")
print(result.output)
# Out:
# Oh my, let’s try to crack this code! 🤔 Isn’t it amusing how we can’t know the weather just by typing? Are you asking about today’s temperature, or are we venturing deeper into Swedish cyber weather sorcery? 😄

# %% [markdown]
# # Check messages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 14, 363224, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in Stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 14, 363566, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 14, 364465, tzinfo=datetime.timezone.utc), run_id='019d6754-0b13-7314-ac5b-be9fa689f100'),
#  ModelResponse(parts=[TextPart(content='Oh my, let’s try to crack this code! 🤔 Isn’t it amusing how we can’t know the weather just by typing? Are you asking about today’s temperature, or are we venturing deeper into Swedish cyber weather sorcery? 😄')], usage=RequestUsage(input_tokens=42, output_tokens=56, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 15, 21877, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 14, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555054-SOVNACkN1PBJjTN6NYSk', finish_reason='stop', run_id='019d6754-0b13-7314-ac5b-be9fa689f100')]

# %%
# Längden på messages
len(messages)
# Out:
# 2

# %% [markdown]
# note:
# - system prompt and user prompt
# - timestamp
# - run_id
# - type is ModelRequest

# %%
# Första meddelandet
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 14, 363224, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in Stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 14, 363566, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 14, 364465, tzinfo=datetime.timezone.utc), run_id='019d6754-0b13-7314-ac5b-be9fa689f100')

# %% [markdown]
# - TextPart
# - metadata (tokens, model, provide)

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content='Oh my, let’s try to crack this code! 🤔 Isn’t it amusing how we can’t know the weather just by typing? Are you asking about today’s temperature, or are we venturing deeper into Swedish cyber weather sorcery? 😄')], usage=RequestUsage(input_tokens=42, output_tokens=56, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 15, 21877, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 14, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555054-SOVNACkN1PBJjTN6NYSk', finish_reason='stop', run_id='019d6754-0b13-7314-ac5b-be9fa689f100')
