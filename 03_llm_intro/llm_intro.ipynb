# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke?"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output="Why don't mathematicians like to play hide and seek?  \n\nBecause good luck hiding when every time you do, someone will look and call your bluff!")

# %%
print(result.output)
# Out:
# Why don't mathematicians like to play hide and seek?
#
# Because good luck hiding when every time you do, someone will look and call your bluff!

# %%
result = await agent.run("What is the weather in Stockholm today?")
print(result.output)
# Out:
# Oh sure, let me check that for you. Because obviously, if I wanted to know the weather, I’d just summon a meteorologist. But I’ll ask you a question: if the weather is cold outside, are you ready to solve 10 more problems instead? 😄 What’s the temperature, anyway?

# %% [markdown]
# # Check messages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 11, 55, 43, 623463, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in Stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 11, 55, 43, 623476, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 11, 55, 43, 623698, tzinfo=datetime.timezone.utc), run_id='019d67cc-6c85-741a-9dbe-b5456d7b1d00'),
#  ModelResponse(parts=[TextPart(content='Oh sure, let me check that for you. Because obviously, if I wanted to know the weather, I’d just summon a meteorologist. But I’ll ask you a question: if the weather is cold outside, are you ready to solve 10 more problems instead? 😄 What’s the temperature, anyway?')], usage=RequestUsage(input_tokens=42, output_tokens=66, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 11, 55, 44, 269955, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 11, 55, 43, tzinfo=TzInfo(0))}, provider_response_id='gen-1775562943-FfkIBWSeE7Cbjax2x38G', finish_reason='stop', run_id='019d67cc-6c85-741a-9dbe-b5456d7b1d00')]

# %%
# Längden på messages
len(messages)
# Out:
# 2

# %% [markdown]
# note:
# - system prompt and user prompt
# - timestamp
# - run_id
# - type is ModelRequest

# %%
# Första meddelandet
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 11, 55, 43, 623463, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What is the weather in Stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 11, 55, 43, 623476, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 11, 55, 43, 623698, tzinfo=datetime.timezone.utc), run_id='019d67cc-6c85-741a-9dbe-b5456d7b1d00')

# %% [markdown]
# - TextPart
# - metadata (tokens, model, provide)

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content='Oh sure, let me check that for you. Because obviously, if I wanted to know the weather, I’d just summon a meteorologist. But I’ll ask you a question: if the weather is cold outside, are you ready to solve 10 more problems instead? 😄 What’s the temperature, anyway?')], usage=RequestUsage(input_tokens=42, output_tokens=66, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 11, 55, 44, 269955, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 11, 55, 43, tzinfo=TzInfo(0))}, provider_response_id='gen-1775562943-FfkIBWSeE7Cbjax2x38G', finish_reason='stop', run_id='019d67cc-6c85-741a-9dbe-b5456d7b1d00')

# %% [markdown]
# ## Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=42, output_tokens=66, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_prompt = "What is the weather in Stockholm today?"

len(user_prompt.split())
# Out:
# 7

# %%
system_prompt = agent._system_prompts[0]
system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'

# %%
len(system_prompt.split())
# Out:
# 17

# %% [markdown]
# user_prompt: 7 word
#
# system_prompt: 17 word
#
# total: 24 words
#
# computed_tokens_approx = 24*1.3 = 31 tokens
#
# input_tokens: 42 tokens
#
# tokens left used for structuring inputs and outputs

# %%
# bot answer computed tokens approx
len(result.output.split())*1.3
# Out:
# 62.400000000000006

# %% [markdown]
# ## Temperature
#
# - higher temperature -> more creativity
# - lower temperature -> closer to deterministic

# %%
from pydantic_ai import ModelSettings

agent = Agent(
    "openrouter:openai/gpt-oss-20b:free",
    system_prompt="You are a children storyteller. Answer max 2 sentences.",
    model_settings=ModelSettings(temperature=0),
)

prompt = "A goldfish in a aquarium ..."

result = await agent.run(prompt)

print(result.output)
# Out:
# In the crystal‑clear aquarium, a tiny goldfish named Gilly twirled around a glittering sea‑glass castle, dreaming of the big blue ocean beyond the glass. Every time the water bubbled, Gilly imagined the waves singing a lullaby that carried her to a world where fish could swim freely under the sun.

# %%
result = await agent.run(prompt)
print(result.output)
# Out:
# In the crystal‑clear aquarium, a tiny goldfish named Glimmer twirled through the bubbles, chasing the dancing light that painted rainbow arcs on the glass. Every day, Glimmer imagined a grand adventure beyond the tank, dreaming of swimming through coral gardens and waving hello to friendly sea turtles.

# %%
agent.model_settings = ModelSettings(temperature=1) # temperature 2
result = await agent.run(prompt)
print(result.output)
# Out:
# In the crystal‑clear tank, a bright goldfish twirled sparkling tails, dreaming of endless oceans, while a curious child traced its silky dance with a finger like a magic wand. When the glass slid open, the goldfish splashed back into an invisible water world, and everyone laughed, knowing that even the tiniest creature can swirl wonder into our hearts.

# %%
# note reasoning tokens as this is a reasoning model
result.usage()
# Out:
# RunUsage(input_tokens=90, cache_read_tokens=80, output_tokens=89, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 5, 'image_tokens': 0}, requests=1)

# %% [markdown]
# ## Multimodal inputs
#
# - text
# - audio
# - image
# - video

# %%
from pathlib import Path
from pydantic_ai.messages import BinaryContent

image_agent = Agent(
    "openrouter:qwen/qwen3.6-plus:free",
    system_prompt="You analyze an image and a text and gives back a funny joke about this image. Max 3 sentences",
)

image_data = Path("bella.png").read_bytes()
prompt = "this is a dog?"

result = await image_agent.run(
    user_prompt=[prompt, BinaryContent(data = image_data, media_type="image/png")]
)

print(result.output)
# Out:
# No, that is definitely a rabbit, but judging by the Swedish-colored ribbons, he's the Captain of the HMS Meatball! He looks ready to sail the seven seas in search of the ultimate carrot.

# %%
image_agent = Agent(
    "openrouter:nvidia/nemotron-nano-12b-v2-vl:free",
    system_prompt="You analyze an image and a text and gives back a funny joke about this image. Max 3 sentences",
)



prompt = "Det här måste vara en katt, det är nog en katt, säg att det är en katt"

result = await image_agent.run(
    user_prompt=[prompt, BinaryContent(data = image_data, media_type="image/png")]
)

print(result.output)
# Out:
# Nah,det的是一只兔子！Hör inte till öronen som sträcker sig rakt upp mot himlen? Och den här banden? Den heter väl inte *Fest *for en katt… 😉 Kanske en spionkanin i aktning?
