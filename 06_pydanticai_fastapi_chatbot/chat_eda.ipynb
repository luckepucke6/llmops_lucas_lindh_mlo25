# %% [markdown]
# # Explore chat in PydanticAI

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv
from constants import MODEL_SMALL, MODEL_MEDIUM, MODEL_LARGE

# overrides eventual caching of enviroment variables so that we can use the latest variables
load_dotenv(override=True)

agent = Agent(
    model=MODEL_SMALL,
    system_prompt="Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.",
    retries=1
)

result = await agent.run("Why is is not sunny in göteborg?")

# %%
print(result.output)
# Out:
# Why is it not sunny in Göteborg? 😄
# Because the code is stuck in a "cloud"! 🌥️🤖
#
# Also, if you're codin', remember: even algorithms need a break from the sun! ☀️❌
#
# Let me know if you want more programming puns! 😊

# %% [markdown]
# test if the model has a memory - sadly it doesn't

# %%
result = await agent.run("What did I just ask you?")

print(result.output)
# Out:
# Ah, the classic question! 🤔
# Looks like you're sparkling with curiosity! 😄
# But let's not overcomplicate things—here's the deal:
# I'm just a little code-writing robot, trying to make you smile. 🤖✨
#
# And speaking of jokes, why did the programmer go broke?
# Because he kept trying to debug his life! 🐛💸
# Let me know if you want more techy humor! 🥳

# %% [markdown]
# ## History stored in all_messages

# %%
result.all_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 8, 615594, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What did I just ask you?', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 8, 615679, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 8, 40, 8, 616072, tzinfo=datetime.timezone.utc), run_id='019d85ff-84a4-76eb-b460-aee2cd5b6c9f'),
#  ModelResponse(parts=[TextPart(content="Ah, the classic question! 🤔  \nLooks like you're sparkling with curiosity! 😄  \nBut let's not overcomplicate things—here's the deal:  \nI'm just a little code-writing robot, trying to make you smile. 🤖✨  \n\nAnd speaking of jokes, why did the programmer go broke?  \nBecause he kept trying to debug his life! 🐛💸  \nLet me know if you want more techy humor! 🥳")], usage=RequestUsage(input_tokens=49, output_tokens=105, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 9, 588988, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 8, 40, 8, tzinfo=TzInfo(0))}, provider_response_id='gen-1776069608-SwPfCgE2pcaIkLw1c7Jp', finish_reason='stop', run_id='019d85ff-84a4-76eb-b460-aee2cd5b6c9f')]

# %%
result = await agent.run(
    "Give me a cool joke about H2O", message_history=result.all_messages()
)
print(result.output)
# Out:
# Why did the water molecule break up with the hydrogen atom?
# Because it found someone better 💧💔
#
# *(P.S. Always remember: Water is the universe's favorite hydrator of life!* 😄)

# %%
result.all_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 8, 615594, tzinfo=datetime.timezone.utc)), UserPromptPart(content='What did I just ask you?', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 8, 615679, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 8, 40, 8, 616072, tzinfo=datetime.timezone.utc), run_id='019d85ff-84a4-76eb-b460-aee2cd5b6c9f'),
#  ModelResponse(parts=[TextPart(content="Ah, the classic question! 🤔  \nLooks like you're sparkling with curiosity! 😄  \nBut let's not overcomplicate things—here's the deal:  \nI'm just a little code-writing robot, trying to make you smile. 🤖✨  \n\nAnd speaking of jokes, why did the programmer go broke?  \nBecause he kept trying to debug his life! 🐛💸  \nLet me know if you want more techy humor! 🥳")], usage=RequestUsage(input_tokens=49, output_tokens=105, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 9, 588988, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 8, 40, 8, tzinfo=TzInfo(0))}, provider_response_id='gen-1776069608-SwPfCgE2pcaIkLw1c7Jp', finish_reason='stop', run_id='019d85ff-84a4-76eb-b460-aee2cd5b6c9f'),
#  ModelRequest(parts=[UserPromptPart(content='Give me a cool joke about H2O', timestamp=datetime.datetime(2026, 4, 13, 8, 46, 14, 390437, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 8, 46, 14, 391047, tzinfo=datetime.timezone.utc), run_id='019d8605-1966-741e-8ed4-9670c80d816a'),
#  ModelResponse(parts=[TextPart(content="Why did the water molecule break up with the hydrogen atom?  \nBecause it found someone better 💧💔  \n\n*(P.S. Always remember: Water is the universe's favorite hydrator of life!* 😄)")], usage=RequestUsage(input_tokens=172, output_tokens=50, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 8, 46, 15, 175624, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 8, 46, 14, tzinfo=TzInfo(0))}, provider_response_id='gen-1776069974-4gdabA8SsCzx39rJrh3Y', finish_reason='stop', run_id='019d8605-1966-741e-8ed4-9670c80d816a')]

# %%
result = await agent.run(
    "What did I just ask you?", message_history=result.all_messages()
)
print(result.output)
# Out:
# You're absolutely spot-on! 🎉 🤓
# So, to recap:
# - You asked about what something "just asked" you
# - And I delivered a playful programming joke with a side of emojis 🤖😄
# - Plus, I added a little techy twist!
#
# It’s like debugging a joke while sipping a coffee ☕. What’s next? 🚀

# %%
result.all_messages()
